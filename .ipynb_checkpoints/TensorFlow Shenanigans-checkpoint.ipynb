# %%
# Initializing Spark
import findspark
findspark.init()

# Importing PySpark related
from pyspark import SparkContext
from pyspark.sql import SparkSession
import collections

# %%
# Importing TensorFlow
import tensorflow as tf
import tensorflowonspark as tfos
from tensorflowonspark import TFCluster # Needs package 'packaging' to be installed manually to run properly

# %%
# Importing other packages
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Hiding pysoundfile warning generated by librosa
import warnings
warnings.filterwarnings("ignore", message="pysoundfile")

# %%
# Testing loading of audio data
data, sampleRate = librosa.load('./data/cv-valid-train/cv-valid-train/sample-000000.mp3', res_type = 'kaiser_fast')

# %%
# Plotting audio wave
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr = sampleRate)

# %%
len(data)
# Out:
# 90494

# %%
librosa.core.get_duration(data)/len(data)
# Out:
# 4.5351473922902495e-05

# %%
testSample = data[1000:1020]

# %%
testSample
# Out:
# array([-0.00078286, -0.00077911, -0.00151317, -0.00165962, -0.00163265,
#        -0.00150514, -0.0012685 , -0.00144022, -0.0013787 , -0.00153125,
#        -0.00146603, -0.00137538, -0.00150461, -0.00127161, -0.00088416,
#        -0.00069222, -0.00116626, -0.00106464, -0.00079209, -0.00086103],
#       dtype=float32)

# %%
test = librosa.stft(testSample, hop_length = 50)

# %%
librosa.display.specshow(test, y_axis='cqt_hz')
