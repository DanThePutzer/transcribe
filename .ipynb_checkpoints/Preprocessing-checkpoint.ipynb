# %% [markdown]
# ### Importing Libraries

# %%
# Initializing Spark
import findspark
findspark.init()

# Importing PySpark related
from pyspark import SparkContext
from pyspark.sql import SparkSession
import collections

# %%
# Importing other packages
import numpy as np
import librosa
import librosa.display
# from pydub import AudioSegment
import io
import os
import soundfile as sf
from IPython import display
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# ### Initializing Spark

# %%
# Creating Spark Session
spark = SparkSession.builder \
    .master('local') \
    .appName('AudioAttempt') \
    .config('spark.executor.memory', '8gb') \
    .getOrCreate()

# %%
# Creating Spark context
context = spark.sparkContext

# %% [markdown]
# ### Loading Demo File

# %%
# Loading audio data into cluster memory as binary
baseAudio = context.binaryFiles('data/train/audio/bird/00f0204f_nohash_2.wav')

# %% [markdown]
# ### Defining Transformer Functions

# %%
# Function to convert audio stored as binary in-memory to numerical data
def binaryToNumerical(x):
    return sf.read(io.BytesIO(x))

# %%
# Function to perform fourier transformation on audio snippets to get energy in different frequency ranges
def fourierTransformation(x):
    return np.abs(librosa.stft(x))

# %%
# Function to split clip into 20ms (320 units) snippets, transform to spectrogram data (through fourier transformation)
# and assemble back together
def processClip(x):
    return transformedAudio(binaryToNumerical(x)[0])

# %% [markdown]
# ### Applying Transformer Functions

# %%
binaryAudio = baseAudio.map(lambda x: x[1])

# %%
numericalAudio = binaryAudio.map(lambda x: binaryToNumerical(x))

# %%
transformedAudio = numericalAudio.map(lambda x: fourierTransformation(x))

# %%
numericalAudio.collect()
# Out:
# [(array([-1.22070312e-04, -4.88281250e-04, -3.35693359e-04, ...,
#           3.05175781e-05,  6.10351562e-05,  3.35693359e-04]), 16000)]

# %%
test = np.array(numericalAudio.collect())
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-14-305e86249b00> in <module>
# ----> 1 test = np.array(numericalAudio.collect())
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\pyspark\rdd.py in collect(self)
#     814         """
#     815         with SCCallSiteSync(self.context) as css:
# --> 816             sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     817         return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#     818
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ...

# %%
test.shape
# Out:
# (16000,)

# %%
librosa.stft(test, hop_length=321)
# Out:
# array([[-6.4284801e-02+0.00000000e+00j, -3.4652989e-02+0.00000000e+00j,
#          1.5609872e-02+0.00000000e+00j, ...,
#         -2.1093649e-04+0.00000000e+00j,  3.5938604e-03+0.00000000e+00j,
#          1.0284379e-02+0.00000000e+00j],
#        [ 1.2930691e-01+4.20128342e-18j,  8.4998738e-03+1.16424471e-01j,
#         -7.5315297e-02-4.98283480e-04j, ...,
#          1.2326641e-02+4.56770044e-03j, -1.1174418e-02+1.61070395e-02j,
#         -1.0330146e-02-7.84853101e-03j],
#        [-2.0215504e-01+4.09020497e-17j,  6.5408990e-02-1.53512210e-01j,
#          8.9916930e-02+6.83910325e-02j, ...,
#         -2.2449035e-02+2.93222498e-02j, -3.4394604e-03-5.55813909e-02j,
#          4.2166825e-02+5.60343228e-02j],
#        ...,
#        [ 2.8025988e-04+9.40492941e-18j,  1.0423124e-04+1.14437426e-04j,
#          3.1737160e-05-6.56728516e-05j, ...,
#          1.8597768e-04+1.66607260e-05j, -1.2737408e-04+3.16366531e-05j,
#         -1.2947243e-05-3.20836727e-04j],
# ...

# %%
lel = librosa.amplitude_to_db(abs(librosa.stft(test, hop_length=321)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d7c38de26ec3> in <module>
# ----> 1 lel = librosa.amplitude_to_db(abs(librosa.stft(test, hop_length=321)))
#
# NameError: name 'test' is not defined

# %%
librosa.display.specshow(lel, sr=16000, x_axis='time', y_axis='hz')

# %%
os.listdir('./data/train/audio/')
# Out:
# ['bed',
#  'bird',
#  'cat',
#  'dog',
#  'down',
#  'eight',
#  'five',
#  'four',
#  'go',
#  'happy',
#  'house',
#  'left',
#  'marvin',
#  'nine',
#  'no',
#  'off',
#  'on',
#  'one',
#  'right',
#  'seven',
#  'sheila',
#  'six',
#  'stop',
#  'three',
#  'tree',
#  'two',
#  'up',
#  'wow',
#  'yes',
#  'zero',
#  '_background_noise_']

# %%
lel.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c9d877fe2dd8> in <module>
# ----> 1 lel.shape
#
# NameError: name 'lel' is not defined

# %%
context._conf.getAll()
# Out:
# [('spark.master', 'local'),
#  ('spark.driver.port', '59655'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.driver.host', '137.208.242.113'),
#  ('spark.app.id', 'local-1580548307350'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.executor.id', 'driver'),
#  ('spark.executor.memory', '2gb'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.app.name', 'AudioAttempt'),
#  ('spark.ui.showConsoleProgress', 'true')]
